# %%
# Import SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
import pandas as pd

# %%
# Import declarative base and set Base variable
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
df = pd.read_csv("data.csv")

# %%
gb = df.groupby("LocationAbbr").mean().reset_index()

# %%
gb.head()
# Out:
#   LocationAbbr     Year  DataValue
# 0           AK  2013.25  36.919444
# 1           AL  2013.25  43.458333
# 2           AR  2013.25  41.886111
# 3           AZ  2013.25  38.686111
# 4           CA  2013.25  38.461111

# %%
average_dict = {}
for index, row in gb.iterrows():
    average_dict.update({row["LocationAbbr"]:row["DataValue"]})

# %%
average_list = []
for index, row in df.iterrows():
    average_list.append(average_dict[row["LocationAbbr"]])

# %%
df["Average"] = average_list

# %%
question_dict = {
    "Prevalence of diagnosed diabetes among adults aged >= 18 years": "Diabetes",
    "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes": "Blood Pressure",
    "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes": "Cholesterol"
}

# %%
question_list = []
for index, row in df.iterrows():
    question_list.append(question_dict[row["Question"]])

# %%
df["AbbrQuestion"] = question_list

# %%
df.head()
# Out:
#    Year LocationAbbr LocationDesc  \
# 0  2013           AL      Alabama
# 1  2015           AL      Alabama
# 2  2011           AL      Alabama
# 3  2011           AL      Alabama
# 4  2013           AL      Alabama
#
#                                             Question  DataValue   Gender  \
# 0  Prevalence of high blood pressure among adults...       79.4   Female
# 1  Prevalence of high blood pressure among adults...       78.6   Female
# 2  Prevalence of high blood pressure among adults...       78.1   Female
# 3  Prevalence of high blood pressure among adults...       77.8  Overall
# 4  Prevalence of high blood pressure among adults...       77.6  Overall
#
#      Average    AbbrQuestion
# 0  43.458333  Blood Pressure
# 1  43.458333  Blood Pressure
# 2  43.458333  Blood Pressure
# 3  43.458333  Blood Pressure
# 4  43.458333  Blood Pressure

# %%
class Data(Base):
    __tablename__ = 'data'
    id = Column(Integer, primary_key=True)
    Year = Column(Integer)
    LocationAbbr = Column(String(255))
    LocationDesc = Column(String(255))
    Question = Column(String(255))
    DataValue = Column(Float)
    Gender = Column(String(255))
    Average = Column(Integer)
    AbbrQuestion = Column(String(255))

# %%
engine = create_engine("sqlite:///diabetes.sqlite")
conn = engine.connect()

# %%
Base.metadata.create_all(conn)

# %%
session = Session(bind=engine)

# %%
x = 1

# %%
for index, row in df.iterrows():
    data = Data(
        id = x,
        Year=row["Year"],
        LocationAbbr = row["LocationAbbr"],
        LocationDesc = row["LocationDesc"],
        Question = row["Question"],
        DataValue = row["DataValue"],
        Gender = row["Gender"],
        Average = row["Average"],
        AbbrQuestion = row["AbbrQuestion"])
    session.add(data)
    session.commit()
    x +=1

# %%
df = pd.read_sql_query("SELECT * FROM data",conn)

# %%
df
# Out:
#         id  Year LocationAbbr LocationDesc  \
# 0        1  2013           AL      Alabama
# 1        2  2015           AL      Alabama
# 2        3  2011           AL      Alabama
# 3        4  2011           AL      Alabama
# 4        5  2013           AL      Alabama
# 5        6  2011           AL      Alabama
# 6        7  2015           AL      Alabama
# 7        8  2015           AL      Alabama
# 8        9  2013           AL      Alabama
# 9       10  2011           AL      Alabama
# 10      11  2011           AL      Alabama
# 11      12  2011           AL      Alabama
# 12      13  2013           AL      Alabama
# 13      14  2015           AL      Alabama
# 14      15  2015           AL      Alabama
# 15      16  2015           AL      Alabama
# 16      17  2013           AL      Alabama
# 17      18  2013           AL      Alabama
# 18      19  2013           AK       Alaska
# 19      20  2011           AK       Alaska
# 20      21  2013           AK       Alaska
# 21      22  2013           AK       Alaska
# 22      23  2015           AK       Alaska
# 23      24  2011           AK       Alaska
# 24      25  2013           AK       Alaska
# 25      26  2013           AK       Alaska
# 26      27  2011           AK       Alaska
